# %% [markdown]
# # Toronto Part 2

# %% [markdown]
# ## 1. Preparing

# %%
import geocoder

import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import requests

wikipedia_link='https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
raw_wikipedia_page= requests.get(wikipedia_link).text

soup = BeautifulSoup(raw_wikipedia_page,'lxml')

# %% [markdown]
# ## 2. Loading Data

# %%
df_lon_lat = pd.read_csv('Geospatial_Coordinates.csv')
df_lon_lat.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %%
df_lon_lat.columns=['Postcode','Latitude','Longitude']
df_lon_lat.head()
# Out:
#   Postcode   Latitude  Longitude
# 0      M1B  43.806686 -79.194353
# 1      M1C  43.784535 -79.160497
# 2      M1E  43.763573 -79.188711
# 3      M1G  43.770992 -79.216917
# 4      M1H  43.773136 -79.239476

# %%
df = pd.read_csv('toronto_part1.csv',index_col=0)


df.head()
# Out:
#   Postcode                                            Borough  \
# 0      M6L                                          Downsview
# 1      M4V                   Deer Park, Rathnelly, South Hill
# 2      M5V  CN Tower, King and Spadina, Railway Lands, Sou...
# 3      M2K                                    Bayview Village
# 4      M4A                                   Victoria Village
#
#                                        Neighbourhood
# 0                                          Downsview
# 1                   Deer Park, Rathnelly, South Hill
# 2  CN Tower, King and Spadina, Railway Lands, Sou...
# 3                                    Bayview Village
# 4                                   Victoria Village

# %% [markdown]
# ## 3. Extracting Lattitudes and Longtitude

# %%
Toronto_df = pd.merge(df,
                 df_lon_lat[['Postcode','Latitude', 'Longitude']],
                 on='Postcode')
Toronto_df
# Out:
#    Postcode                                            Borough  \
# 0       M6L                                          Downsview
# 1       M4V                   Deer Park, Rathnelly, South Hill
# 2       M5V  CN Tower, King and Spadina, Railway Lands, Sou...
# 3       M2K                                    Bayview Village
# 4       M4A                                   Victoria Village
# 5       M3A                                          Parkwoods
# 6       M2J                                         Henry Farm
# 7       M5K           Design Exchange, Toronto Dominion Centre
# 8       M1M                              Cliffcrest, Cliffside
# 9       M1E                             Morningside, West Hill
# 10      M5C                                     St. James Town
# 11      M9N                                             Weston
# 12      M1P  Dorset Park, Scarborough Town Centre, Wexford ...
# 13      M4C                                   Woodbine Heights
# 14      M8W                             Alderwood, Long Branch
# 15      M1B                                     Rouge, Malvern
# 16      M1R                                  Maryvale, Wexford
# 17      M4K                                          Riverdale
# 18      M1X                                        Upper Rouge
# 19      M6K                 Exhibition Place, Parkdale Village
# 20      M9L                                      Humber Summit
# 21      M8X                                       The Kingsway
# 22      M8Y  Humber Bay, Mimico NE, Old Mill South, The Que...
# 23      M6M              Keelesdale, Mount Dennis, Silverthorn
# 24      M2R                                    Willowdale West
# 25      M9B       Islington, Princess Gardens, West Deane Park
# 26      M2L                                         York Mills
# 27      M4L                                       India Bazaar
# 28      M2M                            Newtonbrook, Willowdale
# 29      M8V                                        New Toronto
# ..      ...                                                ...
# 47      M5A                          Harbourfront, Regent Park
# 48      M5E                                        Berczy Park
# 49      M6H                                 Dovercourt Village
# 50      M9R                                  Kingsview Village
# 51      M3H                     Bathurst Manor, Wilson Heights
# 52      M3K                                        CFB Toronto
# 53      M9V  Beaumond Heights, Jamestown, Mount Olive, Silv...
# 54      M4J                                       East Toronto
# 55      M1K                              Ionview, Kennedy Park
# 56      M5S                              University of Toronto
# 57      M3C                                    Flemingdon Park
# 58      M3L                                     Downsview West
# 59      M4X                        Cabbagetown, St. James Town
# 60      M6A                   Lawrence Heights, Lawrence Manor
# 61      M1T                                      Tam O'Shanter
# 62      M2H                                  Hillcrest Village
# 63      M3J                    Northwood Park, York University
# 64      M1N                                        Birch Cliff
# 65      M5P                                  Forest Hill North
